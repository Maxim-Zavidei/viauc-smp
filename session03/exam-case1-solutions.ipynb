# %%
# Libraries
import math
import pandas as pd
import sympy as sp
import numpy as np
from sympy import *
from math import *

# Scipy distributions
from scipy.stats import binom
from scipy.stats import expon
from scipy.stats import geom
from scipy.stats import hypergeom
from scipy.stats import nbinom
from scipy.stats import norm
from scipy.stats import poisson
from scipy.stats import uniform

# Scipy operations
from scipy.integrate import quad
from scipy.misc import derivative
import scipy.integrate as integrate
import scipy.special as special

# Miscellaneous
sp.init_printing()
import matplotlib.pyplot as plt
from fractions import Fraction
from sympy import Rational as R
from IPython.display import display, Math, Latex
# %matplotlib inline
from IPython.display import Image, HTML

# %%
# Section 1
Image('https://cdn.mathpix.com/snip/images/wAN_RsdCTgxkpbYyH_bncZWmcmQAkbvCZXPbcrBKFyw.original.fullsize.png', width = 500)

# %%
# Section 1 - Not practical to solve in Python

# %%
# Section 2
Image('https://cdn.mathpix.com/snip/images/ersxx-8Z_SbhIHEyy1n8enQQY64eTVcJ1Fw3X-TFfhA.original.fullsize.png', width = 500)

# %%
# Section 2 - Not practical to solve in Python

# %%
# Section 3
Image('https://cdn.mathpix.com/snip/images/szmDlxHK1ZnNb2Q4kHVtLziwpCuh4y_kSvitUOxnkjI.original.fullsize.png', width = 500)

# %%
# Section 3
# Question 1)

result = uniform.cdf(5, 0, 10) - uniform.cdf(2, 0, 10)
answer = round(result, 2)

print("Exact result: ", result)
print("Answer = ", answer)
# Out:
# Exact result:  0.3
# Answer =  0.3

# %%
# Question 2)
result = uniform.cdf(2, 0, 10) / uniform.cdf(5, 0, 10)
answer = round(result, 2)

print("Exact result: ", result)
print("Answer = ", answer)
# Out:
# Exact result:  0.4
# Answer =  0.4

# %%
# Question 3)
result = (uniform.cdf(8, 0, 10) - uniform.cdf(4, 0, 10)) / uniform.sf(4, 0, 10)
answer = round(result, 2)

print("Exact result: ", result)
print("Answer = ", answer)
# Out:
# Exact result:  0.6666666666666667
# Answer =  0.67

# %%
# Section 4
Image('https://cdn.mathpix.com/snip/images/oqbDgUJ6g2UFsrkDp2uCWUiMh0M_m7gvc23pGr-mEQs.original.fullsize.png', width = 500)

# %%
# Section 4 - Not practical to solve in Python

# %%
# Section 5
Image('https://cdn.mathpix.com/snip/images/m6w3RBVC1PmbC1OYKqVgySSCbwRm6SqKWcIF0MLbeoI.original.fullsize.png', width = 500)

# %%
# Section 5 - Not practical to solve in Python

# %%
# Section 6
Image('https://cdn.mathpix.com/snip/images/7l8HlaGlEvIxwiq2W-cCN96dBVMdUaVQ2Qha1r0csl8.original.fullsize.png', width = 500)

# %%
# Section 6 - Not practical to solve in Python

# %%
# Section 7
Image('https://cdn.mathpix.com/snip/images/mhLJhjSwe4bLBo-E4i61Qjqyj9df7v45XXg3L5sVYmU.original.fullsize.png', width = 500)

# %%
# Section 7 - Not practical to solve in Python

# %%
# Section 8
Image('https://cdn.mathpix.com/snip/images/vtlk_uyoezSG_3KryCtvPPfUf8E5ecR1huGPs2iFRsk.original.fullsize.png', width = 500)

# %%
# Section 8
# Question 1)

result = (comb(30, 4) + comb(70, 4)) / comb(100, 4)
answer = round(result, 2)

print("Exact result: ", result)
print("Answer = ", answer)
# Out:
# Exact result:  0.24081760164234392
# Answer =  0.24

# %%
# Question 2)

result = (comb(30, 3) * comb(70, 1) + comb(70, 3) * comb(30, 1)) / comb(100, 4)
answer = round(result, 2)

print("Exact result: ", result)
print("Answer = ", answer)
# Out:
# Exact result:  0.4912750479760789
# Answer =  0.49

# %%
# Section 9
Image('https://cdn.mathpix.com/snip/images/5P9aGSt-gBvl52u6aUKm6s21PxyGmSHeWevxSudkNC8.original.fullsize.png', width = 500)

# %%
# Section 9

for i in range(100):
    result = hypergeom.sf(0, 5047, 242, i)
    if result >= 0.9:
        break

print("i: ", i, ", result= ", result)
print("Answer = ", i)
# Out:
# i:  47 , result=  0.901755214555911
# Answer =  47

# %%
# Section 10
Image('https://cdn.mathpix.com/snip/images/SSxSTH8wxJcDRlJBldLhRdP4R7VXte0LXDPxcCHll9g.original.fullsize.png', width = 500)

# %%
# Question 1)
mean = geom.mean(0.08)
answer_mean = round(mean, 2)

print("Exact mean: ", mean)
print("Mean = ", answer_mean)
# Out:
# Exact mean:  12.5
# Mean =  12.5

# %%
# Question 2)
result = geom.pmf(10, 0.08)
answer = round(result, 2)

print("Exact result: ", result)
print("Answer = ", answer)
# Out:
# Exact result:  0.03777290906292455
# Answer =  0.04

# %%
# Question 3)
mean = 10/0.08
answer_mean = round(mean, 2)

print("Exact mean: ", mean)
print("Mean = ", answer_mean)
# Out:
# Exact mean:  125.0
# Mean =  125.0

# %%
# Section 11
Image('https://cdn.mathpix.com/snip/images/1C0iF3Jx38i8LmBkr1l38rygnrrExP9huCzBhcG3IA4.original.fullsize.png', width = 500)

# %%
# Question a)
result = poisson.cdf(14, 10.5)
answer = round(result, 2)

print("Exact result: ", result)
print("Answer = ", answer)
# Out:
# Exact result:  0.8878878776279938
# Answer =  0.89

# %%
# Question b)
result = poisson.pmf(0, 1.75)
answer = round(result, 2)

print("Exact result: ", result)
print("Answer = ", answer)
# Out:
# Exact result:  0.17377394345044514
# Answer =  0.17

# %%
# Question c)
result = poisson.pmf(3, 5.25)
answer = round(result, 2)

print("Exact result: ", result)
print("Answer = ", answer)
# Out:
# Exact result:  0.1265553851427573
# Answer =  0.13

# %%
# Section 12
Image('https://cdn.mathpix.com/snip/images/2kVOvKTbUKpgROM3i9PAGI9OTJVfMHclcyE-JWsaLEw.original.fullsize.png', width = 500)

# %%
# Section 12 - Not practical to solve in Python

# %%
# Section 13
Image('https://cdn.mathpix.com/snip/images/vb8bdOD0WPOPH-N-dpsCJ4n7DyEkxXDFqWuFYkOtNkc.original.fullsize.png', width = 500)

# %%
# Question a)
result = norm.cdf(300, loc = 250, scale = sqrt(391)) - norm.cdf(250, loc = 250, scale = sqrt(391))
answer = round(result, 4)

print("Exact result: ", result)
print("Answer = ", answer)
# Out:
# Exact result:  0.4942742187986622
# Answer =  0.4943

# %%
# Question b)
result = norm.sf(300, loc = 250, scale = sqrt(391))
answer = round(result, 4)

print("Exact result: ", result)
print("Answer = ", answer)
# Out:
# Exact result:  0.005725781201337806
# Answer =  0.0057

# %%
# Question c)
# X ~ Binom(10, prob. from point b) -
# the number of customers out of 10 total that exceed the 300 $ of unusual activity
result = binom.sf(0, 10, norm.sf(300, loc = 250, scale = sqrt(391)))
answer = round(result, 4)

print("Exact result: ", result)
print("Answer = ", answer)
# Out:
# Exact result:  0.05580480824972845
# Answer =  0.0558

# %%
# Section 14
Image('https://cdn.mathpix.com/snip/images/qfK0lJDsrqoUAzTPm9I2M0I80gXH4W3cw5Pz0tDkRh0.original.fullsize.png', width = 500)

# %%
# Question a)
result = expon.cdf(4.5, loc = 0, scale = 6)
answer = round(result, 4)

print("Exact result: ", result)
print("Answer = ", answer)
# Out:
# Exact result:  0.5276334472589853
# Answer =  0.5276

# %%
# Question b)
result = expon.sf(9.5, loc = 0, scale = 6)
answer = round(result, 4)

print("Exact result: ", result)
print("Answer = ", answer)
# Out:
# Exact result:  0.20528965757990927
# Answer =  0.2053

# %%
# Question c)
for i in reversed(range(1, 10000)):
    result = expon.sf(i/10000, loc = 0, scale = 6)
    if result >= 0.9:
        break

print("i: ", i, ", result= ", result)
print("Answer = ", i)
# Out:
# i:  6321 , result=  0.9000094641418044
# Answer =  6321

# %%
# Question b)
result = expon.cdf(9.5, loc = 0, scale = 6)
answer = round(result, 4)

print("Exact result: ", result)
print("Answer = ", answer)
# Out:
# Exact result:  0.7947103424200908
# Answer =  0.7947
