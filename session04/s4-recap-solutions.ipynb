# %%
# Libraries
import math
import pandas as pd
import sympy as smp
import numpy as np
from sympy import *
from math import *

# Scipy distributions
from scipy.stats import binom
from scipy.stats import expon
from scipy.stats import geom
from scipy.stats import hypergeom
from scipy.stats import nbinom
from scipy.stats import norm
from scipy.stats import poisson
from scipy.stats import uniform

# Scipy operations
from scipy.integrate import quad
from scipy.misc import derivative
import scipy.integrate as integrate
import scipy.special as special

# Miscellaneous
smp.init_printing()
import matplotlib.pyplot as plt
from fractions import Fraction
from sympy import Rational as R
from IPython.display import display, Math, Latex
# %matplotlib inline
from IPython.display import Image, HTML

# %%
# Exercise 1
Image('https://cdn.mathpix.com/snip/images/EAtOAVlJvYlzdOVtIEQESs8riCSmkNhZcJI18-BsCFg.original.fullsize.png', width = 500)

# %%
# a)
# x - is the input variable of the cdf we're finding
# c - is the unknown constant in the function
# u - is the input variable of the given pdf
x, u, c = smp.symbols('x u c', real = True)
pdf = c * u**4

smp.integrate(c * u**4, (u, -1, x)).simplify()
# Out:
#   ⎛ 5    ⎞
# c⋅⎝x  + 1⎠
# ──────────
#     5

# %%
# b)
x, c = smp.symbols('x c', real = True)

pdf = c * x**4
result = smp.solve(smp.integrate(c * x**4, (x, -1, 1)) - 1, c)[0]

display(Math("c = " + repr(result)))
# Out:
# $\displaystyle c = 5/2$

# %%
# c)
x = smp.symbols('x', real = True)

cdf = R(5,2) * x**4
result = smp.integrate(cdf, (x, R(-1,2), R(1,2)))

display(Math("P(-1/2 < X < 1/2) = " + repr(result)))

result = smp.integrate(cdf, (x, 0, 1))

display(Math("P(X > 0) = " + repr(result)))
# Out:
# $\displaystyle P(-1/2 < X < 1/2) = 1/32$
# $\displaystyle P(X > 0) = 1/2$

# %%
# d)
x = smp.symbols('x', real = True)

mean_formula = x * R(5,2) * x**4
mean = smp.integrate(mean_formula, (x, -1, 1))

display(Math("E[X] = " + repr(mean)))

variance_formula = x**2 * R(5,2) * x**4
variance = smp.integrate(variance_formula, (x, -1, 1)) - mean**2

display(Math("Var[X] = " + repr(variance)))
# Out:
# $\displaystyle E[X] = 0$
# $\displaystyle Var[X] = 5/7$

# %%
# Exercise 2
Image('https://cdn.mathpix.com/snip/images/j-7NbA8wlzx9QuFq1i1rBkW7uEAt6-wd8y6_6SAFwgs.original.fullsize.png', width = 500)

# %%
# a)
mean_formula = x * R(1,4) * x * smp.exp(-x/2)
mean = smp.integrate(mean_formula, (x, 0, smp.oo))

display(Math("E[X] = " + repr(mean)))
# Out:
# $\displaystyle E[X] = 4$

# %%
# b)
mean_formula = x * 5 * x**(-2)
mean = smp.integrate(mean_formula, (x, 5, smp.oo))

display(Math("E[X] = " + repr(mean)))
# Out:
# $\displaystyle E[X] = oo$

# %%
# c)
a, b = symbols('a b')

eq1 = smp.integrate((a + b * x**2), (x, 0, 1)) - 1
eq2 = smp.integrate(x * (a + b * x**2), (x, 0, 1)) - 3/5

result = solve((eq1, eq2), (a, b))

display(Math(repr(result)))
# Out:
# $\displaystyle {a: 0.600000000000000, b: 1.20000000000000}$
